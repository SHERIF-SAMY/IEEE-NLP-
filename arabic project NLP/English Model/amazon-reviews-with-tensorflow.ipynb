# %% [markdown]
# # 📚 Imports
# ---

# %%
import pandas as pd
import re
import string
import collections
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, SnowballStemmer

import tensorflow as tf
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # 📖 Data
# ---

# %%
df_train = pd.read_csv('/kaggle/input/amazon-reviews/train.csv')
df_test = pd.read_csv('/kaggle/input/amazon-reviews/test.csv')

# %%
df_train.head()
# Out:
#    2                     Stuning even for the non-gamer  \
# 0  2              The best soundtrack ever to anything.
# 1  2                                           Amazing!
# 2  2                               Excellent Soundtrack
# 3  2  Remember, Pull Your Jaw Off The Floor After He...
# 4  2                            an absolute masterpiece
#
#   This sound track was beautiful! It paints the senery in your mind so well I would recomend it even to people who hate vid. game music! I have played the game Chrono Cross but out of all of the games I have ever played it has the best music! It backs away from crude keyboarding and takes a fresher step with grate guitars and soulful orchestras. It would impress anyone who cares to listen! ^_^
# 0  I'm reading a lot of reviews saying that this ...
# 1  This soundtrack is my favorite music of all ti...
# 2  I truly like this soundtrack and I enjoy video...
# 3  If you've played the game, you know how divine...
# 4  I am quite sure any of you actually taking the...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3599999 entries, 0 to 3599998
# Data columns (total 3 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                      Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                                      -----
#  0   2                                                                                                                                                                                                                                                                                                                                                                                                           int64
#  1   Stuning even for the non-gamer                                                                                                                                                                                                                                                                                                                                                                              object
#  2   This sound track was beautiful! It paints the senery in your mind so well I would recomend it even to people who hate vid. game music! I have played the game Chrono Cross but out of all of the games I have ever played it has the best music! It backs away from crude keyboarding and takes a fresher step with grate guitars and soulful orchestras. It would impress anyone who cares to listen! ^_^  object
# dtypes: int64(1), object(2)
# memory usage: 82.4+ MB

# %% [markdown]
# ### Insert columns

# %%
df_train.columns = ['label', 'title', 'text']
df_train.head()
# Out:
#    label                                              title  \
# 0      2              The best soundtrack ever to anything.
# 1      2                                           Amazing!
# 2      2                               Excellent Soundtrack
# 3      2  Remember, Pull Your Jaw Off The Floor After He...
# 4      2                            an absolute masterpiece
#
#                                                 text
# 0  I'm reading a lot of reviews saying that this ...
# 1  This soundtrack is my favorite music of all ti...
# 2  I truly like this soundtrack and I enjoy video...
# 3  If you've played the game, you know how divine...
# 4  I am quite sure any of you actually taking the...

# %%
df_test.columns = ['label', 'title', 'text']
df_test.head()
# Out:
#    label                                              title  \
# 0      2  One of the best game music soundtracks - for a...
# 1      1                   Batteries died within a year ...
# 2      2              works fine, but Maha Energy is better
# 3      2                       Great for the non-audiophile
# 4      1              DVD Player crapped out after one year
#
#                                                 text
# 0  Despite the fact that I have only played a sma...
# 1  I bought this charger in Jul 2003 and it worke...
# 2  Check out Maha Energy's website. Their Powerex...
# 3  Reviewed quite a bit of the combo players and ...
# 4  I also began having the incorrect disc problem...

# %% [markdown]
# ### Using only 50,000 texts for training and 5,000 for validation (anything I raise)

# %%
df_train = df_train.head(100000)
df_test = df_test.head(10000)

# %%
print(df_train['label'].value_counts())
print(df_test['label'].value_counts())
# Out:
# 2    51267
# 1    48733
# Name: label, dtype: int64
# 2    5124
# 1    4876
# Name: label, dtype: int64

# %% [markdown]
# ### I'll join the title with the text because I think the title is shorter, people tend to put keywords in it

# %%
def concat_columns(df, col1, col2, new_col):
    df[new_col] = df[col1].apply(str) + ' ' + df[col2].apply(str)
    df.drop(col2, axis = 1, inplace = True)
    return df

df_train = concat_columns(df_train, 'text', 'title', 'text')
df_test = concat_columns(df_test, 'text', 'title', 'text')

# %% [markdown]
# ### I will change the 'label' column values to 1 -> 0 and 2 -> 1

# %%
df_train['label'] = df_train['label'].map({1:0, 2:1})
df_test['label'] = df_test['label'].map({1:0, 2:1})

# %%
df_train.head()
# Out:
#    label                                               text
# 0      1  I'm reading a lot of reviews saying that this ...
# 1      1  This soundtrack is my favorite music of all ti...
# 2      1  I truly like this soundtrack and I enjoy video...
# 3      1  If you've played the game, you know how divine...
# 4      1  I am quite sure any of you actually taking the...

# %% [markdown]
# ### Now the data is ready for cleaning.

# %% [markdown]
# # ♻️ Data Cleaning
# ---

# %% [markdown]
# ## Function to remove unwanted characters

# %%
def clean_text(text):
    # Remove special characters and numbers
    text = re.sub(r'[^A-Za-zÀ-ú ]+', '', text)
    # Analyzing the most used words below, i chose to exclude these because there are too many and are unnecessary
    text = re.sub('book|one', '', text)
    # Convert to lower case
    text = text.lower()
    # remove scores
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Applying the function
df_train['text'] = df_train['text'].apply(clean_text)
df_test['text'] = df_test['text'].apply(clean_text)

# %% [markdown]
# ## Function to remove stop words

# %%
def remove_stopwords(texto):
    stop_words = set(stopwords.words('english'))
    tokens = nltk.word_tokenize(texto.lower())
    return " ".join([token for token in tokens if token not in stop_words])

# Applying the function
df_train['text'] = df_train['text'].apply(remove_stopwords)
df_test['text'] = df_test['text'].apply(remove_stopwords)

# %% [markdown]
# ## Function to normalize the words

# %%
def normalize_text(text):
    stemmer = SnowballStemmer("english")
    normalized_text = []
    for word in text.split():
        stemmed_word = stemmer.stem(word)
        normalized_text.append(stemmed_word)
    return ' '.join(normalized_text)
    
# Applying the function
df_train['text'] = df_train['text'].apply(normalize_text)
df_test['text'] = df_test['text'].apply(normalize_text)

# %% [markdown]
# # 📊 Top 10 most used words
# ---

# %% [markdown]
# ## Train data

# %%
words = []
for text in df_train['text']:
    words.extend(text.split())
word_count = collections.Counter(words)
top_words = dict(word_count.most_common(10))

# Figure Size
plt.figure(figsize = (10, 6))

# Create the Barplot
plt.bar(range(len(top_words)), list(top_words.values()), align = 'center')

# Creating a y axis with words
plt.xticks(range(len(top_words)), list(top_words.keys()))

# Grid Opacity
plt.grid(alpha = 0.5)

# Title and labels
plt.title('Top 10 most used words', fontsize = 18)
plt.xlabel('Words')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Test data

# %%
words = []
for text in df_test['text']:
    words.extend(text.split())
word_count = collections.Counter(words)
top_words = dict(word_count.most_common(10))

# Figure Size
plt.figure(figsize = (10, 6))

# Create the Barplot
plt.bar(range(len(top_words)), list(top_words.values()), align = 'center')

# Creating a y axis with words
plt.xticks(range(len(top_words)), list(top_words.keys()))

# Grid Opacity
plt.grid(alpha = 0.5)
# Title and labels
plt.title('Top 10 most used words', fontsize = 18)
plt.xlabel('Words')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
#  # 🧬 Text processing
#  ---

# %%
# Maximum number of words to be considered in the vocabulary
max_words = 10000 
# Maximum number of tokens in a sequence
max_len = 200 
# Tokenizer
tokenizer = Tokenizer(num_words = max_words) 
# Snap tokenizer to text data
tokenizer.fit_on_texts(df_train['text']) 
# Converts texts into strings of numbers
sequences_train = tokenizer.texts_to_sequences(df_train['text']) 
sequences_val = tokenizer.texts_to_sequences(df_test['text']) 
# Mapping words to indexes
word_index = tokenizer.word_index

# %%
# Sequence padding
data_train = pad_sequences(sequences_train, maxlen = max_len)
data_val = pad_sequences(sequences_val, maxlen = max_len)

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.svm import SVC
# from sklearn.metrics import accuracy_score, classification_report

# # Assuming 'df' and 'tfidf_matrix' are defined from the previous code

# # Split data into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, df['rating'], test_size=0.2, random_state=42)

# # Initialize and train an SVM model
# svm_model = SVC(kernel='linear') # You can change the kernel if needed
# svm_model.fit(X_train, y_train)

# # Make predictions on the test set
# y_pred = svm_model.predict(X_test)

# # Evaluate the model
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy: {accuracy}")

# print(classification_report(y_test, y_pred))

# %% [markdown]
# # 🤖 Model
# ---

# %%
# Create the model
model = tf.keras.Sequential()
model.add(Embedding(max_words, 16, input_length = max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(1, activation = 'sigmoid'))

# Compile the model
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# Checking summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 200, 16)           160000
#
#  global_average_pooling1d_1   (None, 16)               0
#  (GlobalAveragePooling1D)
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 160,017
# Trainable params: 160,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model
history = model.fit(data_train, df_train['label'], epochs = 30, batch_size = 64, validation_data = (data_val, df_test['label']))
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2377 - accuracy: 0.9067 - val_loss: 0.3061 - val_accuracy: 0.8820
# Epoch 2/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2362 - accuracy: 0.9079 - val_loss: 0.3075 - val_accuracy: 0.8817
# Epoch 3/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2346 - accuracy: 0.9084 - val_loss: 0.3111 - val_accuracy: 0.8787
# Epoch 4/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.2334 - accuracy: 0.9085 - val_loss: 0.3115 - val_accuracy: 0.8806
# Epoch 5/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2320 - accuracy: 0.9092 - val_loss: 0.3132 - val_accuracy: 0.8800
# Epoch 6/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2308 - accuracy: 0.9100 - val_loss: 0.3151 - val_accuracy: 0.8802
# Epoch 7/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2299 - accuracy: 0.9097 - val_loss: 0.3170 - val_accuracy: 0.8785
# Epoch 8/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2288 - accuracy: 0.9102 - val_loss: 0.3179 - val_accuracy: 0.8800
# Epoch 9/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2279 - accuracy: 0.9106 - val_loss: 0.3214 - val_accuracy: 0.8770
# Epoch 10/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2272 - accuracy: 0.9108 - val_loss: 0.3210 - val_accuracy: 0.8796
# Epoch 11/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2262 - accuracy: 0.9115 - val_loss: 0.3229 - val_accuracy: 0.8789
# Epoch 12/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2257 - accuracy: 0.9117 - val_loss: 0.3247 - val_accuracy: 0.8794
# Epoch 13/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2248 - accuracy: 0.9125 - val_loss: 0.3259 - val_accuracy: 0.8786
# Epoch 14/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2243 - accuracy: 0.9122 - val_loss: 0.3279 - val_accuracy: 0.8773
# Epoch 15/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2238 - accuracy: 0.9123 - val_loss: 0.3318 - val_accuracy: 0.8758
# Epoch 16/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2233 - accuracy: 0.9133 - val_loss: 0.3310 - val_accuracy: 0.8764
# Epoch 17/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2228 - accuracy: 0.9126 - val_loss: 0.3325 - val_accuracy: 0.8772
# Epoch 18/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2222 - accuracy: 0.9134 - val_loss: 0.3339 - val_accuracy: 0.8760
# Epoch 19/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2218 - accuracy: 0.9126 - val_loss: 0.3354 - val_accuracy: 0.8758
# Epoch 20/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2214 - accuracy: 0.9136 - val_loss: 0.3369 - val_accuracy: 0.8754
# Epoch 21/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2211 - accuracy: 0.9138 - val_loss: 0.3418 - val_accuracy: 0.8744
# Epoch 22/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2206 - accuracy: 0.9140 - val_loss: 0.3406 - val_accuracy: 0.8749
# Epoch 23/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2202 - accuracy: 0.9143 - val_loss: 0.3407 - val_accuracy: 0.8747
# Epoch 24/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2196 - accuracy: 0.9145 - val_loss: 0.3479 - val_accuracy: 0.8722
# Epoch 25/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2196 - accuracy: 0.9138 - val_loss: 0.3435 - val_accuracy: 0.8732
# Epoch 26/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2193 - accuracy: 0.9142 - val_loss: 0.3452 - val_accuracy: 0.8735
# Epoch 27/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2189 - accuracy: 0.9143 - val_loss: 0.3462 - val_accuracy: 0.8734
# Epoch 28/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2187 - accuracy: 0.9146 - val_loss: 0.3478 - val_accuracy: 0.8726
# Epoch 29/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2184 - accuracy: 0.9148 - val_loss: 0.3481 - val_accuracy: 0.8728
# Epoch 30/30
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.2182 - accuracy: 0.9148 - val_loss: 0.3515 - val_accuracy: 0.8724

# %% [markdown]
# # Evaluate the model
# ---

# %% [markdown]
# ## Accuracy

# %%
loss, accuracy = model.evaluate(data_val, df_test['label'], verbose = 0)
print('Accuracy: %f' % (accuracy*100))
# Out:
# Accuracy: 87.239999

# %% [markdown]
# ## Loss graph

# %%
# Loss graph
plt.style.use('dark_background')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc = 'upper right')
plt.show()

# %% [markdown]
# ## Accuracy graph

# %%
# Accuracy graph
plt.style.use('dark_background')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc = 'lower right')
plt.show()

# %%
model.save("English_review_model.h5")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Load the model
model = load_model("text_classification_model.h5")

# Retrieve the input length from the model's Embedding layer
embedding_layer = model.layers[0]  # Assuming the Embedding layer is the first layer
max_len = embedding_layer.input_length  # This should match the training max_len (200)

# Define the function
def predict_text_classification(text, model, tokenizer, max_len):

    # Preprocess the input text
    sequences = tokenizer.texts_to_sequences([text])  # Convert text to sequence of integers
    padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post', truncating='post')
    
    # Make prediction
    prediction = model.predict(padded_sequences, verbose=0)
    
    return prediction[0][0]

# Example: Load or fit a tokenizer
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(df_train['text'])  # Use your training data text column

# Test the function
text = "This product is amazing and works perfectly!"
prediction = predict_text_classification(text, model, tokenizer, max_len)

print(f"Predicted Probability: {prediction}")
if prediction > 0.5:
    print("Predicted Class: Positive")
else:
    print("Predicted Class: Negative")
# Out:
# Predicted Probability: 0.5606996417045593
# Predicted Class: Positive

# %% [markdown]
# # 🏁 Thank you! Feel free to criticize! 🏁¶
